# %%
#Q1.  What is a Decision Tree, and how does it work
'''
Decision tree is supervised machine learning algorithm. we can used decision tree classification for classification problems and decision tree regression for regression problems.
decision tree have nested if- else loop structure.
decision tree captures non-linear data and devides it into nodes.
decision tree keep spliting untli all the same data into in same class.
the decision tree intend is to create leaf node where each data point belongs to one class. 
'''

# %%
#Q2. What are impurity measures in Decision Trees
'''
in decision tree impurity nodes means errors or misclassified data pints.
impurity measures: 
    1. classification error 
    2. Gini
    3.Entropy
'''

# %%
#Q3.  What is the mathematical formula for Gini Impurity
'''
mathematical formula for gini : Pi(1-Pi)
for to class: 1-[(Po)**2 + (Px)**2]
'''

# %%
#Q4.  What is the mathematical formula for Entropy
'''
mathematical formula for Entropy: -Pi(log2)Pi
'''

# %%
#Q5. What is Information Gain, and how is it used in Decision Trees
'''
Information gain is statistical metrics used to determine how well an attribute can split data into subsets.
it is used in decision tree to find best split for node.
'''

# %%
#Q6.  What is the difference between Gini Impurity and Entropy
'''
mathematical formula of gini: Pi(1-Pi)
mathematical formula of Entropy: -Pi(log2)Pi

becouse of entropy have log function it takes more time for cumputation .
gini is faster campured to entropy.
'''

# %%
#Q7.  What is the mathematical explanation behind Decision Trees
'''
Structure: Decision Trees consist of nodes (decision points), branches (outcomes), and leaves (final predictions).
Splitting: At each node, the data is split based on a feature to maximize "purity". Common criteria include:
    Gini Impurity: Measures misclassification.
    Entropy: Measures randomness.
    Information Gain: Reduction in entropy after the split.
'''

# %%
#Q8.  What is Pre-Pruning in Decision Trees
'''
decison tree is greddy algorithm , that keeps splitting untill every leaf node is pure node. it memorized the data its lead to overfitting.
to avoid these problem we can used some techniques like pre-pruning , post-pruning and ensembles techniques.
in pre-prununing we can construct a decision tree using hyperparameter tunning . in that we can used different params like criterian , splitter,max_depth and max_features.

'''

# %%
#Q9. What is Post-Pruning in Decision Trees
'''
Post-pruning is technique which is used to avoid overfitting.
in post pruning first we construct entire tree then we cut last unneccery nodes to avoid overfitting.
'''

# %%
#Q10.  What is the difference between Pre-Pruning and Post-Pruning
'''
pre-pruning done before construct decision tree with the help of hyperparameter tuning.
post-pruning done after construct decision tree. it it we just cut unneccesary last nodes.
'''

# %%
#Q11.  What is a Decision Tree Regressor
'''
Decision Tree regressor is used for regression problem.
'''

# %%
#Q12. What are the advantages and disadvantages of Decision Trees
'''
Advantage:
Simple to understand.
Capture non-linear relationship.
decision tree devides the data into nodes. it devides untill all the same data are in same class.
the decision tree intent is to create leaf node where each data points belongs to one class.
'''

# %%
#Q13.  How does a Decision Tree handle missing values
'''
If the missing values are infrequent, they might be ignored during training.
OR we can used cetral tendacy method based on behavior of data.
'''

# %%
#Q14. How does a Decision Tree handle categorical features
'''
in decision tree we can handle categorical feature using One-hot-encoding or label-encoding methods.
'''

# %%
#Q15.  What are some real-world applications of Decision Trees?
'''
Healthcare
Finance
Marketing
Retail
'''

# %%
#Q16. Write a Python program to train a Decision Tree Classifier on the Iris dataset and print the model accuracy
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np 

data = load_iris()
df = pd.DataFrame(data=data.data,columns=data.feature_names)
df['target'] = data.target

x = df.drop('target',axis = 1)
y = df['target']

from sklearn.model_selection import train_test_split
x_train ,x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=2)

model = DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
score = accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.9333333333333333

# %%
#Q17.  Write a Python program to train a Decision Tree Classifier using Gini Impurity as the criterion and print the feature importances
model = DecisionTreeClassifier(criterion='gini')
model.fit(x_train,y_train)
model.feature_importances_
# Out:
# array([0.        , 0.01879699, 0.53058783, 0.45061517])

# %%
#Q18.  Write a Python program to train a Decision Tree Classifier using Entropy as the splitting criterion and print the model accuracy
model = DecisionTreeClassifier(criterion='entropy')
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

score = accuracy_score(y_test,y_pred)
print(score)
# Out:
# 0.9333333333333333

# %%
#Q19.  Write a Python program to train a Decision Tree Regressor on a housing dataset and evaluate using Mean Squared Error (MSE)
from sklearn.datasets import fetch_california_housing
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
data = fetch_california_housing()
df = pd.DataFrame(data = data.data , columns=data.feature_names)
df['target'] = data.target
x = df.iloc[:,:-1]
y = df.iloc[:,-1]
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=2)
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(criterion='squared_error')
std = StandardScaler()
# x_train_std = std.fit_transform(x_train)
# x_test_std = std.transform(x_test)


model.fit(x_train , y_train)
y_pred = model.predict(x_test)
score = mean_squared_error(y_test,y_pred)
print(score)
# Out:
# 0.5660290359976743

# %%
#Q20.  Write a Python program to train a Decision Tree Classifier and visualize the tree using graphviz
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import graphviz

# Sample dataset
data = {
    'Feature1': [2, 3, 5, 7, 11],
    'Feature2': [1, 0, 1, 0, 1],
    'Label': [0, 1, 0, 1, 0]
}

# Creating DataFrame
df = pd.DataFrame(data)

# Features and Labels
X = df[['Feature1', 'Feature2']]
y = df['Label']

# Train the Decision Tree Classifier
clf = DecisionTreeClassifier()
clf.fit(X, y)

# Visualize the tree
dot_data = tree.export_graphviz(clf, out_file=None, 
                                feature_names=['Feature1', 'Feature2'],  
                                class_names=['Class0', 'Class1'],  
                                filled=True, rounded=True,  
                                special_characters=True)  

# Use graphviz to create and view the tree
graph = graphviz.Source(dot_data)  
graph.render("decision_tree")
graph.view()

# %%
#Q21. Write a Python program to train a Decision Tree Classifier with a maximum depth of 3 and compare its accuracy with a fully grown tree
model = DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
score1 = accuracy_score(y_test,y_pred)
print("Accuracy of fuly grown tree: ",score1)

model2 = DecisionTreeClassifier(max_depth=3)
model2.fit(x_train,y_train)
y_pred1 = model2.predict(x_test)
score2 = accuracy_score(y_test,y_pred)
print("Accuracy score of decision tree those maximum depth is 3: ",score2)
# Out:
# Accuracy of fuly grown tree:  0.9333333333333333
# Accuracy score of decision tree those maximum depth is 3:  0.9333333333333333

# %%
#Q22.  Write a Python program to train a Decision Tree Classifier using min_samples_split=5 and compare its accuracy with a default tree
model3 = DecisionTreeClassifier(min_samples_split=5)
model3.fit(x_train,y_train)
y_pred = model3.predict(x_test)
score3 = accuracy_score(y_test,y_pred)
print(f"decision tree accuracy using min_sample_split: {score3} ,\ndefault tree accuracy:{score1}")
# Out:
# decision tree accuracy using min_sample_split: 0.9666666666666667 ,
# default tree accuracy:0.9333333333333333

# %%
#Q23. Write a Python program to apply feature scaling before training a Decision Tree Classifier and compare its accuracy with unscaled data

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np 
from sklearn.preprocessing import StandardScaler

data = load_iris()
df = pd.DataFrame(data=data.data,columns=data.feature_names)
df['target'] = data.target

x = df.drop('target',axis = 1)
y = df['target']

from sklearn.model_selection import train_test_split
x_train ,x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=2)

std = StandardScaler()
x_train_std = std.fit_transform(x_train)
x_test_std = std.transform(x_test)


model = DecisionTreeClassifier()
model.fit(x_train,y_train)
y_pred1 = model.predict(x_test)
score1 = accuracy_score(y_test,y_pred1)
print(score1)

model.fit(x_train_std,y_train)
y_pred2 = model.predict(x_test_std)
score2 = accuracy_score(y_test,y_pred2)
print(score2)
# Out:
# 0.9333333333333333
# 0.9333333333333333

# %%
#Q24. Write a Python program to train a Decision Tree Classifier using One-vs-Rest (OvR) strategy for multiclass classification
from sklearn.datasets import make_classification
x,y = make_classification(n_samples=1000,n_classes=3,n_features=10,n_informative=6,random_state=2)
model = DecisionTreeClassifier()

x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=2)
from sklearn.multiclass import OneVsRestClassifier
model1 = OneVsRestClassifier(model)

model1.fit(x_train , y_train)
y_pred = model1.predict(x_test)

score = accuracy_score(y_test,y_pred)
print(score*100)
# Out:
# 65.5

# %%
#Q25. Write a Python program to train a Decision Tree Classifier and display the feature importance scores

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np 

data = load_iris()
df = pd.DataFrame(data=data.data,columns=data.feature_names)
df['target'] = data.target

x = df.drop('target',axis = 1)
y = df['target']

from sklearn.model_selection import train_test_split
x_train ,x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=2)

model = DecisionTreeClassifier()
model.fit(x_train,y_train)

feature_importances = clf.feature_importances_
for feature, importance in zip(x.columns, feature_importances):
    print(f"{feature}: {importance:.2f}")
# Out:
# sepal length (cm): 0.00
# sepal width (cm): 1.00

# %%
#Q26. Write a Python program to train a Decision Tree Regressor with max_depth=5 and compare its performance with an unrestricted tree
from sklearn.datasets import fetch_california_housing
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
data = fetch_california_housing()
df = pd.DataFrame(data = data.data , columns=data.feature_names)
df['target'] = data.target
x = df.iloc[:,:-1]
y = df.iloc[:,-1]
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=2)
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model2 = DecisionTreeRegressor(max_depth=5)

from sklearn.metrics import r2_score

model.fit(x_train , y_train)
model2.fit(x_train , y_train)
y_pred1 = model.predict(x_test)
y_pred2 = model2.predict(x_test)
score = r2_score(y_test,y_pred1)
score1 = r2_score(y_test,y_pred2)
print(score)
print(score1)
# Out:
# 0.5887641268492626
# 0.6094854552954491

# %%
#Q27. Write a Python program to train a Decision Tree Classifier, apply Cost Complexity Pruning (CCP), and visualize its effect on accuracy

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree

# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# Pruning the tree using Cost Complexity Pruning (CCP)
path = clf.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas = path.ccp_alphas

# Train and evaluate decision trees for different values of ccp_alpha
clfs = []
train_scores = []
test_scores = []

for ccp_alpha in ccp_alphas:
    clf = DecisionTreeClassifier(random_state=42, ccp_alpha=ccp_alpha)
    clf.fit(X_train, y_train)
    clfs.append(clf)
    train_scores.append(accuracy_score(y_train, clf.predict(X_train)))
    test_scores.append(accuracy_score(y_test, clf.predict(X_test)))

# Plot the effect of CCP on accuracy
plt.figure(figsize=(10, 6))
plt.plot(ccp_alphas, train_scores, marker='o', label='Train', drawstyle="steps-post")
plt.plot(ccp_alphas, test_scores, marker='o', label='Test', drawstyle="steps-post")
plt.xlabel('CCP Alpha')
plt.ylabel('Accuracy')
plt.title('Effect of Cost Complexity Pruning on Accuracy')
plt.legend()
plt.grid()
plt.show()

# Visualize the best pruned tree
best_alpha = ccp_alphas[np.argmax(test_scores)]
best_clf = DecisionTreeClassifier(random_state=42, ccp_alpha=best_alpha)
best_clf.fit(X_train, y_train)

plt.figure(figsize=(20, 10))
plot_tree(best_clf, filled=True, feature_names=iris.feature_names, class_names=iris.target_names)
plt.title(f'Decision Tree with CCP Alpha = {best_alpha}')
plt.show()

# %%
#Q28. Write a Python program to train a Decision Tree Classifier and evaluate its performance using Precision, Recall, and F1-Score
# Import necessary libraries
import numpy as np
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report

# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Evaluate the performance using Precision, Recall, and F1-Score
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f'Precision: {precision:.2f}')
print(f'Recall: {recall:.2f}')
print(f'F1-Score: {f1:.2f}')

# Detailed classification report
print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# Precision: 1.00
# Recall: 1.00
# F1-Score: 1.00
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
#Q29.  Write a Python program to train a Decision Tree Classifier and visualize the confusion matrix using seaborn
# Import necessary libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test)

# Compute the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix of Decision Tree Classifier')
plt.show()

# %%
#Q30.  Write a Python program to train a Decision Tree Classifier and use GridSearchCV to find the optimal values for max_depth and min_samples_split
from sklearn.model_selection import GridSearchCV
model = DecisionTreeClassifier()
from sklearn.datasets import make_classification
x,y = make_classification(n_samples=100,n_classes=2,n_features=4)

x_train,x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=2)

params = {'max_depth':[1,2,3,4,5,6,7,8],'min_samples_split':[4,5,6,7,8,9]}

clf = GridSearchCV(model,param_grid=params,scoring='accuracy',verbose=2)
clf.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] END ...................max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=4; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=5; total time=   0.0s
# [CV] END ...................max_depth=1, min_samples_split=6; total time=   0.0s
# ...
